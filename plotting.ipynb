# %%
import matplotlib.pyplot as plt
import numpy as np

# create 1000 equally spaced points between -6 and 6
x = np.linspace(-6, 6, 1000)

# calculate the y value for each element of the x vector
y = x**2

fig, ax = plt.subplots()
ax.grid(True)
ax.plot(x, y)
